# %%
import requests
import pandas as pd
import numpy as np
from sklearn.linear_model import Ridge, Lasso, LinearRegression
from sklearn.metrics import root_mean_squared_error

# %% [markdown]
# ## Data Loading

# %%
# !mkdir data

# %%
files = [('green_tripdata_2024-10.parquet', './data'), 
         ('green_tripdata_2024-11.parquet', './data')]

print("Downloading started:...")

for file, path in files:
    url = f"https://d37ci6vzurychx.cloudfront.net/trip-data/{file}"
    save_path = f"{path}/{file}"
    response = requests.get(url, stream=True)

    with open(save_path, "wb") as handle:
        for data in response.iter_content(chunk_size=1024):
            handle.write(data)
# Out:
# Downloading started:...

# %%
train_data = pd.read_parquet("data/green_tripdata_2024-10.parquet")
test_data = pd.read_parquet("data/green_tripdata_2024-11.parquet")

# %%
train_data.head()
# Out:
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0         2  2024-10-01 00:52:13   2024-10-01 01:02:39                  N
# 1         2  2024-10-01 00:56:34   2024-10-01 01:03:51                  N
# 2         2  2024-10-01 00:23:31   2024-10-01 00:45:17                  N
# 3         2  2024-10-01 00:25:02   2024-10-01 00:37:16                  N
# 4         2  2024-10-01 00:11:11   2024-10-01 00:25:43                  N
#
#    RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0         1.0            75           238              1.0           2.10
# 1         1.0           134            82              1.0           4.86
# 2         1.0           202           260              1.0           3.77
# 3         1.0           130           218              1.0           3.11
# 4         1.0            42            94              2.0           4.48
#
#    fare_amount  extra  mta_tax  tip_amount  tolls_amount  ehail_fee  \
# 0         12.8    1.0      0.5         0.0           0.0        NaN
# 1         19.8    1.0      0.5         0.0           0.0        NaN
# 2         22.6    1.0      0.5         0.0           0.0        NaN
# 3         15.6    1.0      0.5         0.0           0.0        NaN
# 4         21.9    1.0      0.5         1.0           0.0        NaN
#
#    improvement_surcharge  total_amount  payment_type  trip_type  \
# 0                    1.0         18.05           1.0        1.0
# 1                    1.0         22.30           2.0        1.0
# 2                    1.0         25.10           2.0        1.0
# 3                    1.0         18.10           2.0        1.0
# 4                    1.0         25.40           1.0        1.0
#
#    congestion_surcharge
# 0                  2.75
# 1                  0.00
# 2                  0.00
# 3                  0.00
# 4                  0.00

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56147 entries, 0 to 56146
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   VendorID               56147 non-null  int32
#  1   lpep_pickup_datetime   56147 non-null  datetime64[us]
#  2   lpep_dropoff_datetime  56147 non-null  datetime64[us]
#  3   store_and_fwd_flag     54502 non-null  object
#  4   RatecodeID             54502 non-null  float64
#  5   PULocationID           56147 non-null  int32
#  6   DOLocationID           56147 non-null  int32
#  7   passenger_count        54502 non-null  float64
#  8   trip_distance          56147 non-null  float64
#  9   fare_amount            56147 non-null  float64
#  10  extra                  56147 non-null  float64
#  11  mta_tax                56147 non-null  float64
#  12  tip_amount             56147 non-null  float64
#  13  tolls_amount           56147 non-null  float64
#  14  ehail_fee              0 non-null      float64
#  15  improvement_surcharge  56147 non-null  float64
#  16  total_amount           56147 non-null  float64
#  17  payment_type           54502 non-null  float64
#  18  trip_type              54497 non-null  float64
#  19  congestion_surcharge   54502 non-null  float64
# dtypes: datetime64[us](2), float64(14), int32(3), object(1)
# memory usage: 7.9+ MB

# %%
num_features = ['total_amount', 'trip_distance', 'passenger_count']
cat_features = ['PULocationID', 'DOLocationID']

# %%
def preprocessing(data):
    data['duration'] = data['lpep_dropoff_datetime'] - data['lpep_pickup_datetime']
    data.duration = data.duration.apply(lambda td: td.total_seconds()/60)
    data = data[(data.duration >= 3.) & (data.duration <= 90.)] 
    data.fillna(0, inplace=True) #maybe debug this later
    return data

# %%
X_train = preprocessing(train_data)[num_features + cat_features]
y_train = preprocessing(train_data)['duration']

X_test = preprocessing(test_data)[num_features + cat_features]
y_test = preprocessing(test_data)['duration']
# Out:
# /var/folders/90/8_2t0pfn6svg2_9zl_0rfx3w0000gn/T/ipykernel_2287/3509260369.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.fillna(0, inplace=True)
# /var/folders/90/8_2t0pfn6svg2_9zl_0rfx3w0000gn/T/ipykernel_2287/3509260369.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.fillna(0, inplace=True)
# /var/folders/90/8_2t0pfn6svg2_9zl_0rfx3w0000gn/T/ipykernel_2287/3509260369.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.fillna(0, inplace=True)
# /var/folders/90/8_2t0pfn6svg2_9zl_0rfx3w0000gn/T/ipykernel_2287/3509260369.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.fillna(0, inplace=True)

# %%
X_train[X_train.passenger_count == np.nan]
# Out:
# Empty DataFrame
# Columns: [total_amount, trip_distance, passenger_count, PULocationID, DOLocationID]
# Index: []

# %%
X_train.isnull().sum()
# Out:
# total_amount       0
# trip_distance      0
# passenger_count    0
# PULocationID       0
# DOLocationID       0
# dtype: int64

# %%
X_test.isnull().sum()
# Out:
# total_amount       0
# trip_distance      0
# passenger_count    0
# PULocationID       0
# DOLocationID       0
# dtype: int64

# %%
X_test.loc[0].values
# Out:
# array([68.75,  6.68,  1.  , 97.  , 50.  ])

# %%
y_test[0]
# Out:
# np.float64(40.416666666666664)

# %% [markdown]
# ## Baseline model

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
train_pred = model.predict(X_train)
root_mean_squared_error(train_pred, y_train)
# Out:
# 6.929022561152728

# %%
test_pred = model.predict(X_test)
root_mean_squared_error(test_pred, y_test)
# Out:
# 6.671806092249931

# %%
test_pred.mean(), test_pred.std()
# Out:
# (np.float64(15.068721986079776), np.float64(7.186011922929579))

# %% [markdown]
# ## Experiments

# %%
import mlflow
import xgboost

# %%
mlflow.set_tracking_uri('sqlite:///mlflow.db')

# %%
mlflow.set_experiment('experiment_1')
# Out:
# 2025/02/10 14:59:10 INFO mlflow.tracking.fluent: Experiment with name 'experiment_1' does not exist. Creating a new experiment.
# <Experiment: artifact_location='/Users/emelidral/Dev/iml/mlruns/1', creation_time=1739174350542, experiment_id='1', last_update_time=1739174350542, lifecycle_stage='active', name='experiment_1', tags={}>

# %%
with mlflow.start_run():
    mlflow.set_tag("workspace", "inclass")
    mlflow.log_param("train_data", "data/green_tripdata_2024-10.parquet")
    mlflow.log_param("test_data", "data/green_tripdata_2024-11.parquet")
    model = LinearRegression()
    model.fit(X_train, y_train)

    test_pred = model.predict(X_test)
    rmse = root_mean_squared_error(test_pred, y_test)
    mlflow.log_metric("rmse", rmse)

# %%
mlflow.end_run()

# %% [markdown]
# ## Mlflow autolog

# %%
mlflow.sklearn.autolog()
model = Lasso(alpha=0.5)
model.fit(X_train, y_train)
# Out:
# 2025/02/10 15:07:45 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '703e432e43bf482e85ac11c537a679ff', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow
# 2025/02/10 15:07:45 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/opt/homebrew/Caskroom/miniconda/base/envs/iml_env/lib/python3.11/site-packages/mlflow/types/utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2025/02/10 15:07:45 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/opt/homebrew/Caskroom/miniconda/base/envs/iml_env/lib/python3.11/site-packages/mlflow/types/utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# Lasso(alpha=0.5)

# %% [markdown]
# ## Hyper Parameter Optimization

# %%
! pip install optuna
# Out:
# Collecting optuna
#   Using cached optuna-4.2.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: alembic>=1.5.0 in /opt/homebrew/Caskroom/miniconda/base/envs/iml_env/lib/python3.11/site-packages (from optuna) (1.14.1)
# Collecting colorlog (from optuna)
#   Using cached colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in /opt/homebrew/Caskroom/miniconda/base/envs/iml_env/lib/python3.11/site-packages (from optuna) (2.2.2)
# Requirement already satisfied: packaging>=20.0 in /opt/homebrew/Caskroom/miniconda/base/envs/iml_env/lib/python3.11/site-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /opt/homebrew/Caskroom/miniconda/base/envs/iml_env/lib/python3.11/site-packages (from optuna) (2.0.38)
# Collecting tqdm (from optuna)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: PyYAML in /opt/homebrew/Caskroom/miniconda/base/envs/iml_env/lib/python3.11/site-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /opt/homebrew/Caskroom/miniconda/base/envs/iml_env/lib/python3.11/site-packages (from alembic>=1.5.0->optuna) (1.3.9)
# Requirement already satisfied: typing-extensions>=4 in /opt/homebrew/Caskroom/miniconda/base/envs/iml_env/lib/python3.11/site-packages (from alembic>=1.5.0->optuna) (4.12.2)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /opt/homebrew/Caskroom/miniconda/base/envs/iml_env/lib/python3.11/site-packages (from Mako->alembic>=1.5.0->optuna) (3.0.2)
# Using cached optuna-4.2.0-py3-none-any.whl (383 kB)
# Using cached colorlog-6.9.0-py3-none-any.whl (11 kB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Installing collected packages: tqdm, colorlog, optuna
# Successfully installed colorlog-6.9.0 optuna-4.2.0 tqdm-4.67.1

# %%
import optuna

# %%
def objective(trial):
    with mlflow.start_run():
        params = {
            #'learning_rate':trial.suggest_float('learning_rate', 1e-10, 1e10, log=True),
            'max_depth': trial.suggest_int('max_depth', 4, 20),
            'reg_alpha': trial.suggest_loguniform('reg_alpha', 1e-5, 1e-1),
            'min_child_weight': trial.suggest_loguniform('min_child_weight', 0.1, 10),
            'objective': 'reg:squarederror'
        }
    
        model = xgboost.XGBRegressor(**params)
        model.fit(X_train, y_train)
        test_pred = model.predict(X_test)
        rmse = root_mean_squared_error(test_pred, y_test)
        mlflow.log_params(params)
        mlflow.log_metric('rmse', rmse)
        return rmse

# %%
study = optuna.create_study()
study.optimize(objective, n_trials=6)
# Out:
# [I 2025-02-10 15:33:07,102] A new study created in memory with name: no-name-c98e07ce-5839-47ce-bc4e-4aef63da932b
# /var/folders/90/8_2t0pfn6svg2_9zl_0rfx3w0000gn/T/ipykernel_2287/1256259272.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 1e-5, 1e-1),
# /var/folders/90/8_2t0pfn6svg2_9zl_0rfx3w0000gn/T/ipykernel_2287/1256259272.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'min_child_weight': trial.suggest_loguniform('min_child_weight', 0.1, 10),
# 2025/02/10 15:33:07 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/opt/homebrew/Caskroom/miniconda/base/envs/iml_env/lib/python3.11/site-packages/mlflow/types/utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2025/02/10 15:33:07 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/opt/homebrew/Caskroom/miniconda/base/envs/iml_env/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:33:07] WARNING: /Users/runner/work/xgboost/xgboost/src/c_api/c_api.cc:1374: Saving model in the UBJSON format as default.  You can use file extension: `json`, `ubj` or `deprecated` to choose between formats."
# 2025/02/10 15:33:10 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/opt/homebrew/Caskroom/miniconda/base/envs/iml_env/lib/python3.11/site-packages/mlflow/types/utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# [I 2025-02-10 15:33:10,209] Trial 0 finished with value: 4.799095475534573 and parameters: {'max_depth': 8, 'reg_alpha': 1.3890786999443535e-05, 'min_child_weight': 3.2639892350382445}. Best is trial 0 with value: 4.799095475534573.
# /var/folders/90/8_2t0pfn6svg2_9zl_0rfx3w0000gn/T/ipykernel_2287/1256259272.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 1e-5, 1e-1),
# /var/folders/90/8_2t0pfn6svg2_9zl_0rfx3w0000gn/T/ipykernel_2287/1256259272.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'min_child_weight': trial.suggest_loguniform('min_child_weight', 0.1, 10),
# 2025/02/10 15:33:14 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/opt/homebrew/Caskroom/miniconda/base/envs/iml_env/lib/python3.11/site-packages/mlflow/types/utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2025/02/10 15:33:14 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/opt/homebrew/Caskroom/miniconda/base/envs/iml_env/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:33:14] WARNING: /Users/runner/work/xgboost/xgboost/src/c_api/c_api.cc:1374: Saving model in the UBJSON format as default.  You can use file extension: `json`, `ubj` or `deprecated` to choose between formats."
# 2025/02/10 15:33:17 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/opt/homebrew/Caskroom/miniconda/base/envs/iml_env/lib/python3.11/site-packages/mlflow/types/utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# [I 2025-02-10 15:33:17,621] Trial 1 finished with value: 5.244096627656075 and parameters: {'max_depth': 20, 'reg_alpha': 0.028149554530345833, 'min_child_weight': 0.30356629651673045}. Best is trial 0 with value: 4.799095475534573.
# /var/folders/90/8_2t0pfn6svg2_9zl_0rfx3w0000gn/T/ipykernel_2287/1256259272.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 1e-5, 1e-1),
# /var/folders/90/8_2t0pfn6svg2_9zl_0rfx3w0000gn/T/ipykernel_2287/1256259272.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'min_child_weight': trial.suggest_loguniform('min_child_weight', 0.1, 10),
# 2025/02/10 15:33:18 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/opt/homebrew/Caskroom/miniconda/base/envs/iml_env/lib/python3.11/site-packages/mlflow/types/utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2025/02/10 15:33:18 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/opt/homebrew/Caskroom/miniconda/base/envs/iml_env/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:33:18] WARNING: /Users/runner/work/xgboost/xgboost/src/c_api/c_api.cc:1374: Saving model in the UBJSON format as default.  You can use file extension: `json`, `ubj` or `deprecated` to choose between formats."
# 2025/02/10 15:33:21 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/opt/homebrew/Caskroom/miniconda/base/envs/iml_env/lib/python3.11/site-packages/mlflow/types/utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# [I 2025-02-10 15:33:21,066] Trial 2 finished with value: 4.9575708531289 and parameters: {'max_depth': 14, 'reg_alpha': 0.00019773445155862822, 'min_child_weight': 4.355519431545143}. Best is trial 0 with value: 4.799095475534573.
# /var/folders/90/8_2t0pfn6svg2_9zl_0rfx3w0000gn/T/ipykernel_2287/1256259272.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 1e-5, 1e-1),
# /var/folders/90/8_2t0pfn6svg2_9zl_0rfx3w0000gn/T/ipykernel_2287/1256259272.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'min_child_weight': trial.suggest_loguniform('min_child_weight', 0.1, 10),
# 2025/02/10 15:33:21 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/opt/homebrew/Caskroom/miniconda/base/envs/iml_env/lib/python3.11/site-packages/mlflow/types/utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2025/02/10 15:33:21 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/opt/homebrew/Caskroom/miniconda/base/envs/iml_env/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:33:21] WARNING: /Users/runner/work/xgboost/xgboost/src/c_api/c_api.cc:1374: Saving model in the UBJSON format as default.  You can use file extension: `json`, `ubj` or `deprecated` to choose between formats."
# 2025/02/10 15:33:24 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/opt/homebrew/Caskroom/miniconda/base/envs/iml_env/lib/python3.11/site-packages/mlflow/types/utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# [I 2025-02-10 15:33:24,577] Trial 3 finished with value: 5.031111100380337 and parameters: {'max_depth': 12, 'reg_alpha': 0.0024176928360142426, 'min_child_weight': 0.7360110265115721}. Best is trial 0 with value: 4.799095475534573.
# /var/folders/90/8_2t0pfn6svg2_9zl_0rfx3w0000gn/T/ipykernel_2287/1256259272.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 1e-5, 1e-1),
# /var/folders/90/8_2t0pfn6svg2_9zl_0rfx3w0000gn/T/ipykernel_2287/1256259272.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'min_child_weight': trial.suggest_loguniform('min_child_weight', 0.1, 10),
# 2025/02/10 15:33:25 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/opt/homebrew/Caskroom/miniconda/base/envs/iml_env/lib/python3.11/site-packages/mlflow/types/utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2025/02/10 15:33:25 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/opt/homebrew/Caskroom/miniconda/base/envs/iml_env/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:33:25] WARNING: /Users/runner/work/xgboost/xgboost/src/c_api/c_api.cc:1374: Saving model in the UBJSON format as default.  You can use file extension: `json`, `ubj` or `deprecated` to choose between formats."
# 2025/02/10 15:33:28 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/opt/homebrew/Caskroom/miniconda/base/envs/iml_env/lib/python3.11/site-packages/mlflow/types/utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# [I 2025-02-10 15:33:28,202] Trial 4 finished with value: 4.968081541786119 and parameters: {'max_depth': 12, 'reg_alpha': 0.042659951378707935, 'min_child_weight': 0.24830277692833283}. Best is trial 0 with value: 4.799095475534573.
# /var/folders/90/8_2t0pfn6svg2_9zl_0rfx3w0000gn/T/ipykernel_2287/1256259272.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha', 1e-5, 1e-1),
# /var/folders/90/8_2t0pfn6svg2_9zl_0rfx3w0000gn/T/ipykernel_2287/1256259272.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'min_child_weight': trial.suggest_loguniform('min_child_weight', 0.1, 10),
# 2025/02/10 15:33:28 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/opt/homebrew/Caskroom/miniconda/base/envs/iml_env/lib/python3.11/site-packages/mlflow/types/utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2025/02/10 15:33:28 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/opt/homebrew/Caskroom/miniconda/base/envs/iml_env/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:33:28] WARNING: /Users/runner/work/xgboost/xgboost/src/c_api/c_api.cc:1374: Saving model in the UBJSON format as default.  You can use file extension: `json`, `ubj` or `deprecated` to choose between formats."
# 2025/02/10 15:33:31 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/opt/homebrew/Caskroom/miniconda/base/envs/iml_env/lib/python3.11/site-packages/mlflow/types/utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# [I 2025-02-10 15:33:31,410] Trial 5 finished with value: 4.727144313107067 and parameters: {'max_depth': 7, 'reg_alpha': 8.676949985124119e-05, 'min_child_weight': 1.0657267002989208}. Best is trial 5 with value: 4.727144313107067.

# %% [markdown]
# ## MLflow client

# %%
from mlflow.tracking import MlflowClient

# %%
from mlflow.entities import ViewType

# %%
client = MlflowClient("sqlite:///mlflow.db")

# %%
old_experiment = client.get_experiment_by_name("experiment_1")

# %%
old_experiment
# Out:
# <Experiment: artifact_location='/Users/emelidral/Dev/iml/mlruns/1', creation_time=1739174350542, experiment_id='1', last_update_time=1739174350542, lifecycle_stage='active', name='experiment_1', tags={}>

# %%
runs = client.search_runs(
    experiment_ids='1',
    run_view_type=ViewType.ACTIVE_ONLY,
    max_results=10,
    filter_string='metrics.rmse < 10',
)

# %%
runs
# Out:
# [<Run: data=<RunData: metrics={'rmse': 4.727144313107067}, params={'base_score': 'None',
#   'booster': 'None',
#   'colsample_bylevel': 'None',
#   'colsample_bynode': 'None',
#   'colsample_bytree': 'None',
#   'custom_metric': 'None',
#   'device': 'None',
#   'early_stopping_rounds': 'None',
#   'eval_metric': 'None',
#   'gamma': 'None',
#   'grow_policy': 'None',
#   'interaction_constraints': 'None',
#   'learning_rate': 'None',
#   'max_bin': 'None',
#   'max_cat_threshold': 'None',
#   'max_cat_to_onehot': 'None',
#   'max_delta_step': 'None',
#   'max_depth': '7',
#   'max_leaves': 'None',
#   'maximize': 'None',
#   'min_child_weight': '1.0657267002989208',
#   'monotone_constraints': 'None',
#   'multi_strategy': 'None',
#   'n_jobs': 'None',
#   'num_boost_round': '100',
#   'num_parallel_tree': 'None',
#   'objective': 'reg:squarederror',
#   'random_state': 'None',
#   'reg_alpha': '8.676949985124119e-05',
#   'reg_lambda': 'None',
#   'sampling_method': 'None',
#   'scale_pos_weight': 'None',
#   'subsample': 'None',
#   'tree_method': 'None',
#   'validate_parameters': 'None',
#   'verbose_eval': 'True',
#   'verbosity': 'None'}, tags={'mlflow.log-model.history': '[{"run_id": "370958a8e9dd4b1db4c15d033d97005d", '
#                               '"artifact_path": "model", "utc_time_created": '
#                               '"2025-02-10 08:33:28.536514", "model_uuid": '
#                               '"226fd86c00e7499385c1dc3147b39ef0", "flavors": '
#                               '{"python_function": {"loader_module": '
#                               '"mlflow.xgboost", "python_version": "3.11.11", '
#                               '"data": "model.xgb", "env": {"conda": '
#                               '"conda.yaml", "virtualenv": "python_env.yaml"}}, '
#                               '"xgboost": {"xgb_version": "2.1.4", "data": '
#                               '"model.xgb", "model_class": '
#                               '"xgboost.sklearn.XGBRegressor", "model_format": '
#                               '"xgb", "code": null}}}]',
#   'mlflow.runName': 'delicate-cow-543',
#   'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/iml_env/lib/python3.11/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'emelidral'}>, info=<RunInfo: artifact_uri='/Users/emelidral/Dev/iml/mlruns/1/370958a8e9dd4b1db4c15d033d97005d/artifacts', end_time=1739176411407, experiment_id='1', lifecycle_stage='active', run_id='370958a8e9dd4b1db4c15d033d97005d', run_name='delicate-cow-543', run_uuid='370958a8e9dd4b1db4c15d033d97005d', start_time=1739176408203, status='FINISHED', user_id='emelidral'>, inputs=<RunInputs: dataset_inputs=[<DatasetInput: dataset=<Dataset: digest='b253d6c6', name='dataset', profile=('{"features_shape": [52837, 5], "features_size": 264185, "features_nbytes": '
#   '1056740}'), schema=('{"mlflow_tensorspec": {"features": "[{\\"type\\": \\"tensor\\", '
#   '\\"tensor-spec\\": {\\"dtype\\": \\"float32\\", \\"shape\\": [-1, 5]}}]", '
#   '"targets": null}}'), source=('{"tags": {"mlflow.user": "emelidral", "mlflow.source.name": '
#   '"/opt/homebrew/Caskroom/miniconda/base/envs/iml_env/lib/python3.11/site-packages/ipykernel_launcher.py", '
#   '"mlflow.source.type": "LOCAL"}}'), source_type='code'>, tags=[<InputTag: key='mlflow.data.context', value='train'>]>,
#   <DatasetInput: dataset=<Dataset: digest='cdcfc2bc', name='dataset', profile='{"num_rows": 49164, "num_elements": 245820}', schema=('{"mlflow_colspec": [{"type": "double", "name": "total_amount", "required": '
#   'true}, {"type": "double", "name": "trip_distance", "required": true}, '
#   '{"type": "double", "name": "passenger_count", "required": true}, {"type": '
#   '"integer", "name": "PULocationID", "required": true}, {"type": "integer", '
#   '"name": "DOLocationID", "required": true}]}'), source=('{"tags": {"mlflow.user": "emelidral", "mlflow.source.name": '
#   '"/opt/homebrew/Caskroom/miniconda/base/envs/iml_env/lib/python3.11/site-packages/ipykernel_launcher.py", '
#   '"mlflow.source.type": "LOCAL"}}'), source_type='code'>, tags=[<InputTag: key='mlflow.data.context', value='eval'>]>]>>,
#  <Run: data=<RunData: metrics={'rmse': 4.968081541786119}, params={'base_score': 'None',
#   'booster': 'None',
#   'colsample_bylevel': 'None',
#   'colsample_bynode': 'None',
#   'colsample_bytree': 'None',
#   'custom_metric': 'None',
#   'device': 'None',
#   'early_stopping_rounds': 'None',
#   'eval_metric': 'None',
#   'gamma': 'None',
#   'grow_policy': 'None',
#   'interaction_constraints': 'None',
#   'learning_rate': 'None',
#   'max_bin': 'None',
#   'max_cat_threshold': 'None',
#   'max_cat_to_onehot': 'None',
#   'max_delta_step': 'None',
#   'max_depth': '12',
#   'max_leaves': 'None',
#   'maximize': 'None',
#   'min_child_weight': '0.24830277692833283',
#   'monotone_constraints': 'None',
#   'multi_strategy': 'None',
#   'n_jobs': 'None',
#   'num_boost_round': '100',
#   'num_parallel_tree': 'None',
#   'objective': 'reg:squarederror',
#   'random_state': 'None',
#   'reg_alpha': '0.042659951378707935',
#   'reg_lambda': 'None',
#   'sampling_method': 'None',
#   'scale_pos_weight': 'None',
#   'subsample': 'None',
#   'tree_method': 'None',
#   'validate_parameters': 'None',
#   'verbose_eval': 'True',
#   'verbosity': 'None'}, tags={'mlflow.log-model.history': '[{"run_id": "7c5a6121cfb14fcb90956ba3b6345f14", '
#                               '"artifact_path": "model", "utc_time_created": '
#                               '"2025-02-10 08:33:25.295469", "model_uuid": '
#                               '"21a69fe59f1c48f98301435df5b39c01", "flavors": '
#                               '{"python_function": {"loader_module": '
#                               '"mlflow.xgboost", "python_version": "3.11.11", '
#                               '"data": "model.xgb", "env": {"conda": '
#                               '"conda.yaml", "virtualenv": "python_env.yaml"}}, '
#                               '"xgboost": {"xgb_version": "2.1.4", "data": '
#                               '"model.xgb", "model_class": '
#                               '"xgboost.sklearn.XGBRegressor", "model_format": '
#                               '"xgb", "code": null}}}]',
#   'mlflow.runName': 'big-steed-316',
#   'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/iml_env/lib/python3.11/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'emelidral'}>, info=<RunInfo: artifact_uri='/Users/emelidral/Dev/iml/mlruns/1/7c5a6121cfb14fcb90956ba3b6345f14/artifacts', end_time=1739176408198, experiment_id='1', lifecycle_stage='active', run_id='7c5a6121cfb14fcb90956ba3b6345f14', run_name='big-steed-316', run_uuid='7c5a6121cfb14fcb90956ba3b6345f14', start_time=1739176404579, status='FINISHED', user_id='emelidral'>, inputs=<RunInputs: dataset_inputs=[<DatasetInput: dataset=<Dataset: digest='b253d6c6', name='dataset', profile=('{"features_shape": [52837, 5], "features_size": 264185, "features_nbytes": '
#   '1056740}'), schema=('{"mlflow_tensorspec": {"features": "[{\\"type\\": \\"tensor\\", '
#   '\\"tensor-spec\\": {\\"dtype\\": \\"float32\\", \\"shape\\": [-1, 5]}}]", '
#   '"targets": null}}'), source=('{"tags": {"mlflow.user": "emelidral", "mlflow.source.name": '
#   '"/opt/homebrew/Caskroom/miniconda/base/envs/iml_env/lib/python3.11/site-packages/ipykernel_launcher.py", '
#   '"mlflow.source.type": "LOCAL"}}'), source_type='code'>, tags=[<InputTag: key='mlflow.data.context', value='train'>]>,
#   <DatasetInput: dataset=<Dataset: digest='cdcfc2bc', name='dataset', profile='{"num_rows": 49164, "num_elements": 245820}', schema=('{"mlflow_colspec": [{"type": "double", "name": "total_amount", "required": '
#   'true}, {"type": "double", "name": "trip_distance", "required": true}, '
#   '{"type": "double", "name": "passenger_count", "required": true}, {"type": '
#   '"integer", "name": "PULocationID", "required": true}, {"type": "integer", '
#   '"name": "DOLocationID", "required": true}]}'), source=('{"tags": {"mlflow.user": "emelidral", "mlflow.source.name": '
#   '"/opt/homebrew/Caskroom/miniconda/base/envs/iml_env/lib/python3.11/site-packages/ipykernel_launcher.py", '
#   '"mlflow.source.type": "LOCAL"}}'), source_type='code'>, tags=[<InputTag: key='mlflow.data.context', value='eval'>]>]>>,
#  <Run: data=<RunData: metrics={'rmse': 5.031111100380337}, params={'base_score': 'None',
#   'booster': 'None',
#   'colsample_bylevel': 'None',
#   'colsample_bynode': 'None',
#   'colsample_bytree': 'None',
#   'custom_metric': 'None',
#   'device': 'None',
#   'early_stopping_rounds': 'None',
#   'eval_metric': 'None',
#   'gamma': 'None',
#   'grow_policy': 'None',
#   'interaction_constraints': 'None',
#   'learning_rate': 'None',
#   'max_bin': 'None',
#   'max_cat_threshold': 'None',
#   'max_cat_to_onehot': 'None',
#   'max_delta_step': 'None',
#   'max_depth': '12',
#   'max_leaves': 'None',
#   'maximize': 'None',
#   'min_child_weight': '0.7360110265115721',
#   'monotone_constraints': 'None',
#   'multi_strategy': 'None',
#   'n_jobs': 'None',
#   'num_boost_round': '100',
#   'num_parallel_tree': 'None',
#   'objective': 'reg:squarederror',
#   'random_state': 'None',
#   'reg_alpha': '0.0024176928360142426',
#   'reg_lambda': 'None',
#   'sampling_method': 'None',
#   'scale_pos_weight': 'None',
#   'subsample': 'None',
#   'tree_method': 'None',
#   'validate_parameters': 'None',
#   'verbose_eval': 'True',
#   'verbosity': 'None'}, tags={'mlflow.log-model.history': '[{"run_id": "e7fa20b742ff4661b02eb42696d5b363", '
#                               '"artifact_path": "model", "utc_time_created": '
#                               '"2025-02-10 08:33:21.782426", "model_uuid": '
#                               '"55e53e57681b4c3281c0579977347111", "flavors": '
#                               '{"python_function": {"loader_module": '
#                               '"mlflow.xgboost", "python_version": "3.11.11", '
#                               '"data": "model.xgb", "env": {"conda": '
#                               '"conda.yaml", "virtualenv": "python_env.yaml"}}, '
#                               '"xgboost": {"xgb_version": "2.1.4", "data": '
#                               '"model.xgb", "model_class": '
#                               '"xgboost.sklearn.XGBRegressor", "model_format": '
#                               '"xgb", "code": null}}}]',
#   'mlflow.runName': 'incongruous-moth-962',
#   'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/iml_env/lib/python3.11/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'emelidral'}>, info=<RunInfo: artifact_uri='/Users/emelidral/Dev/iml/mlruns/1/e7fa20b742ff4661b02eb42696d5b363/artifacts', end_time=1739176404573, experiment_id='1', lifecycle_stage='active', run_id='e7fa20b742ff4661b02eb42696d5b363', run_name='incongruous-moth-962', run_uuid='e7fa20b742ff4661b02eb42696d5b363', start_time=1739176401068, status='FINISHED', user_id='emelidral'>, inputs=<RunInputs: dataset_inputs=[<DatasetInput: dataset=<Dataset: digest='b253d6c6', name='dataset', profile=('{"features_shape": [52837, 5], "features_size": 264185, "features_nbytes": '
#   '1056740}'), schema=('{"mlflow_tensorspec": {"features": "[{\\"type\\": \\"tensor\\", '
#   '\\"tensor-spec\\": {\\"dtype\\": \\"float32\\", \\"shape\\": [-1, 5]}}]", '
#   '"targets": null}}'), source=('{"tags": {"mlflow.user": "emelidral", "mlflow.source.name": '
#   '"/opt/homebrew/Caskroom/miniconda/base/envs/iml_env/lib/python3.11/site-packages/ipykernel_launcher.py", '
#   '"mlflow.source.type": "LOCAL"}}'), source_type='code'>, tags=[<InputTag: key='mlflow.data.context', value='train'>]>,
#   <DatasetInput: dataset=<Dataset: digest='cdcfc2bc', name='dataset', profile='{"num_rows": 49164, "num_elements": 245820}', schema=('{"mlflow_colspec": [{"type": "double", "name": "total_amount", "required": '
#   'true}, {"type": "double", "name": "trip_distance", "required": true}, '
#   '{"type": "double", "name": "passenger_count", "required": true}, {"type": '
#   '"integer", "name": "PULocationID", "required": true}, {"type": "integer", '
#   '"name": "DOLocationID", "required": true}]}'), source=('{"tags": {"mlflow.user": "emelidral", "mlflow.source.name": '
#   '"/opt/homebrew/Caskroom/miniconda/base/envs/iml_env/lib/python3.11/site-packages/ipykernel_launcher.py", '
#   '"mlflow.source.type": "LOCAL"}}'), source_type='code'>, tags=[<InputTag: key='mlflow.data.context', value='eval'>]>]>>,
#  <Run: data=<RunData: metrics={'rmse': 4.9575708531289}, params={'base_score': 'None',
#   'booster': 'None',
#   'colsample_bylevel': 'None',
#   'colsample_bynode': 'None',
#   'colsample_bytree': 'None',
#   'custom_metric': 'None',
#   'device': 'None',
#   'early_stopping_rounds': 'None',
#   'eval_metric': 'None',
#   'gamma': 'None',
#   'grow_policy': 'None',
#   'interaction_constraints': 'None',
#   'learning_rate': 'None',
#   'max_bin': 'None',
#   'max_cat_threshold': 'None',
#   'max_cat_to_onehot': 'None',
#   'max_delta_step': 'None',
#   'max_depth': '14',
#   'max_leaves': 'None',
#   'maximize': 'None',
#   'min_child_weight': '4.355519431545143',
#   'monotone_constraints': 'None',
#   'multi_strategy': 'None',
#   'n_jobs': 'None',
#   'num_boost_round': '100',
#   'num_parallel_tree': 'None',
#   'objective': 'reg:squarederror',
#   'random_state': 'None',
#   'reg_alpha': '0.00019773445155862822',
#   'reg_lambda': 'None',
#   'sampling_method': 'None',
#   'scale_pos_weight': 'None',
#   'subsample': 'None',
#   'tree_method': 'None',
#   'validate_parameters': 'None',
#   'verbose_eval': 'True',
#   'verbosity': 'None'}, tags={'mlflow.log-model.history': '[{"run_id": "266d4e30d42b4a6fb70685b429117374", '
#                               '"artifact_path": "model", "utc_time_created": '
#                               '"2025-02-10 08:33:18.271445", "model_uuid": '
#                               '"6015b32c468b4ba09c4bb6b9eeff6851", "flavors": '
#                               '{"python_function": {"loader_module": '
#                               '"mlflow.xgboost", "python_version": "3.11.11", '
#                               '"data": "model.xgb", "env": {"conda": '
#                               '"conda.yaml", "virtualenv": "python_env.yaml"}}, '
#                               '"xgboost": {"xgb_version": "2.1.4", "data": '
#                               '"model.xgb", "model_class": '
#                               '"xgboost.sklearn.XGBRegressor", "model_format": '
#                               '"xgb", "code": null}}}]',
#   'mlflow.runName': 'receptive-pug-399',
#   'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/iml_env/lib/python3.11/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'emelidral'}>, info=<RunInfo: artifact_uri='/Users/emelidral/Dev/iml/mlruns/1/266d4e30d42b4a6fb70685b429117374/artifacts', end_time=1739176401063, experiment_id='1', lifecycle_stage='active', run_id='266d4e30d42b4a6fb70685b429117374', run_name='receptive-pug-399', run_uuid='266d4e30d42b4a6fb70685b429117374', start_time=1739176397623, status='FINISHED', user_id='emelidral'>, inputs=<RunInputs: dataset_inputs=[<DatasetInput: dataset=<Dataset: digest='b253d6c6', name='dataset', profile=('{"features_shape": [52837, 5], "features_size": 264185, "features_nbytes": '
#   '1056740}'), schema=('{"mlflow_tensorspec": {"features": "[{\\"type\\": \\"tensor\\", '
#   '\\"tensor-spec\\": {\\"dtype\\": \\"float32\\", \\"shape\\": [-1, 5]}}]", '
#   '"targets": null}}'), source=('{"tags": {"mlflow.user": "emelidral", "mlflow.source.name": '
#   '"/opt/homebrew/Caskroom/miniconda/base/envs/iml_env/lib/python3.11/site-packages/ipykernel_launcher.py", '
#   '"mlflow.source.type": "LOCAL"}}'), source_type='code'>, tags=[<InputTag: key='mlflow.data.context', value='train'>]>,
#   <DatasetInput: dataset=<Dataset: digest='cdcfc2bc', name='dataset', profile='{"num_rows": 49164, "num_elements": 245820}', schema=('{"mlflow_colspec": [{"type": "double", "name": "total_amount", "required": '
#   'true}, {"type": "double", "name": "trip_distance", "required": true}, '
#   '{"type": "double", "name": "passenger_count", "required": true}, {"type": '
#   '"integer", "name": "PULocationID", "required": true}, {"type": "integer", '
#   '"name": "DOLocationID", "required": true}]}'), source=('{"tags": {"mlflow.user": "emelidral", "mlflow.source.name": '
#   '"/opt/homebrew/Caskroom/miniconda/base/envs/iml_env/lib/python3.11/site-packages/ipykernel_launcher.py", '
#   '"mlflow.source.type": "LOCAL"}}'), source_type='code'>, tags=[<InputTag: key='mlflow.data.context', value='eval'>]>]>>,
#  <Run: data=<RunData: metrics={'rmse': 5.244096627656075}, params={'base_score': 'None',
#   'booster': 'None',
#   'colsample_bylevel': 'None',
#   'colsample_bynode': 'None',
#   'colsample_bytree': 'None',
#   'custom_metric': 'None',
#   'device': 'None',
#   'early_stopping_rounds': 'None',
#   'eval_metric': 'None',
#   'gamma': 'None',
#   'grow_policy': 'None',
#   'interaction_constraints': 'None',
#   'learning_rate': 'None',
#   'max_bin': 'None',
#   'max_cat_threshold': 'None',
#   'max_cat_to_onehot': 'None',
#   'max_delta_step': 'None',
#   'max_depth': '20',
#   'max_leaves': 'None',
#   'maximize': 'None',
#   'min_child_weight': '0.30356629651673045',
#   'monotone_constraints': 'None',
#   'multi_strategy': 'None',
#   'n_jobs': 'None',
#   'num_boost_round': '100',
#   'num_parallel_tree': 'None',
#   'objective': 'reg:squarederror',
#   'random_state': 'None',
#   'reg_alpha': '0.028149554530345833',
#   'reg_lambda': 'None',
#   'sampling_method': 'None',
#   'scale_pos_weight': 'None',
#   'subsample': 'None',
#   'tree_method': 'None',
#   'validate_parameters': 'None',
#   'verbose_eval': 'True',
#   'verbosity': 'None'}, tags={'mlflow.log-model.history': '[{"run_id": "eef5837f253c4df4b936d27f3a1bda2f", '
#                               '"artifact_path": "model", "utc_time_created": '
#                               '"2025-02-10 08:33:14.580848", "model_uuid": '
#                               '"f31b0fcb43ae40ed84d5cc2312a192be", "flavors": '
#                               '{"python_function": {"loader_module": '
#                               '"mlflow.xgboost", "python_version": "3.11.11", '
#                               '"data": "model.xgb", "env": {"conda": '
#                               '"conda.yaml", "virtualenv": "python_env.yaml"}}, '
#                               '"xgboost": {"xgb_version": "2.1.4", "data": '
#                               '"model.xgb", "model_class": '
#                               '"xgboost.sklearn.XGBRegressor", "model_format": '
#                               '"xgb", "code": null}}}]',
#   'mlflow.runName': 'classy-duck-54',
#   'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/iml_env/lib/python3.11/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'emelidral'}>, info=<RunInfo: artifact_uri='/Users/emelidral/Dev/iml/mlruns/1/eef5837f253c4df4b936d27f3a1bda2f/artifacts', end_time=1739176397615, experiment_id='1', lifecycle_stage='active', run_id='eef5837f253c4df4b936d27f3a1bda2f', run_name='classy-duck-54', run_uuid='eef5837f253c4df4b936d27f3a1bda2f', start_time=1739176390210, status='FINISHED', user_id='emelidral'>, inputs=<RunInputs: dataset_inputs=[<DatasetInput: dataset=<Dataset: digest='b253d6c6', name='dataset', profile=('{"features_shape": [52837, 5], "features_size": 264185, "features_nbytes": '
#   '1056740}'), schema=('{"mlflow_tensorspec": {"features": "[{\\"type\\": \\"tensor\\", '
#   '\\"tensor-spec\\": {\\"dtype\\": \\"float32\\", \\"shape\\": [-1, 5]}}]", '
#   '"targets": null}}'), source=('{"tags": {"mlflow.user": "emelidral", "mlflow.source.name": '
#   '"/opt/homebrew/Caskroom/miniconda/base/envs/iml_env/lib/python3.11/site-packages/ipykernel_launcher.py", '
#   '"mlflow.source.type": "LOCAL"}}'), source_type='code'>, tags=[<InputTag: key='mlflow.data.context', value='train'>]>,
#   <DatasetInput: dataset=<Dataset: digest='cdcfc2bc', name='dataset', profile='{"num_rows": 49164, "num_elements": 245820}', schema=('{"mlflow_colspec": [{"type": "double", "name": "total_amount", "required": '
#   'true}, {"type": "double", "name": "trip_distance", "required": true}, '
#   '{"type": "double", "name": "passenger_count", "required": true}, {"type": '
#   '"integer", "name": "PULocationID", "required": true}, {"type": "integer", '
#   '"name": "DOLocationID", "required": true}]}'), source=('{"tags": {"mlflow.user": "emelidral", "mlflow.source.name": '
#   '"/opt/homebrew/Caskroom/miniconda/base/envs/iml_env/lib/python3.11/site-packages/ipykernel_launcher.py", '
#   '"mlflow.source.type": "LOCAL"}}'), source_type='code'>, tags=[<InputTag: key='mlflow.data.context', value='eval'>]>]>>,
#  <Run: data=<RunData: metrics={'rmse': 4.799095475534573}, params={'base_score': 'None',
#   'booster': 'None',
#   'colsample_bylevel': 'None',
#   'colsample_bynode': 'None',
#   'colsample_bytree': 'None',
#   'custom_metric': 'None',
#   'device': 'None',
#   'early_stopping_rounds': 'None',
#   'eval_metric': 'None',
#   'gamma': 'None',
#   'grow_policy': 'None',
#   'interaction_constraints': 'None',
#   'learning_rate': 'None',
#   'max_bin': 'None',
#   'max_cat_threshold': 'None',
#   'max_cat_to_onehot': 'None',
#   'max_delta_step': 'None',
#   'max_depth': '8',
#   'max_leaves': 'None',
#   'maximize': 'None',
#   'min_child_weight': '3.2639892350382445',
#   'monotone_constraints': 'None',
#   'multi_strategy': 'None',
#   'n_jobs': 'None',
#   'num_boost_round': '100',
#   'num_parallel_tree': 'None',
#   'objective': 'reg:squarederror',
#   'random_state': 'None',
#   'reg_alpha': '1.3890786999443535e-05',
#   'reg_lambda': 'None',
#   'sampling_method': 'None',
#   'scale_pos_weight': 'None',
#   'subsample': 'None',
#   'tree_method': 'None',
#   'validate_parameters': 'None',
#   'verbose_eval': 'True',
#   'verbosity': 'None'}, tags={'mlflow.log-model.history': '[{"run_id": "351a8aca818642ecaa31f88741b25cd1", '
#                               '"artifact_path": "model", "utc_time_created": '
#                               '"2025-02-10 08:33:07.441639", "model_uuid": '
#                               '"e7d902375cb74fa1a5e0c9b7c9046470", "flavors": '
#                               '{"python_function": {"loader_module": '
#                               '"mlflow.xgboost", "python_version": "3.11.11", '
#                               '"data": "model.xgb", "env": {"conda": '
#                               '"conda.yaml", "virtualenv": "python_env.yaml"}}, '
#                               '"xgboost": {"xgb_version": "2.1.4", "data": '
#                               '"model.xgb", "model_class": '
#                               '"xgboost.sklearn.XGBRegressor", "model_format": '
#                               '"xgb", "code": null}}}]',
#   'mlflow.runName': 'mysterious-snail-465',
#   'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/iml_env/lib/python3.11/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'emelidral'}>, info=<RunInfo: artifact_uri='/Users/emelidral/Dev/iml/mlruns/1/351a8aca818642ecaa31f88741b25cd1/artifacts', end_time=1739176390206, experiment_id='1', lifecycle_stage='active', run_id='351a8aca818642ecaa31f88741b25cd1', run_name='mysterious-snail-465', run_uuid='351a8aca818642ecaa31f88741b25cd1', start_time=1739176387107, status='FINISHED', user_id='emelidral'>, inputs=<RunInputs: dataset_inputs=[<DatasetInput: dataset=<Dataset: digest='b253d6c6', name='dataset', profile=('{"features_shape": [52837, 5], "features_size": 264185, "features_nbytes": '
#   '1056740}'), schema=('{"mlflow_tensorspec": {"features": "[{\\"type\\": \\"tensor\\", '
#   '\\"tensor-spec\\": {\\"dtype\\": \\"float32\\", \\"shape\\": [-1, 5]}}]", '
#   '"targets": null}}'), source=('{"tags": {"mlflow.user": "emelidral", "mlflow.source.name": '
#   '"/opt/homebrew/Caskroom/miniconda/base/envs/iml_env/lib/python3.11/site-packages/ipykernel_launcher.py", '
#   '"mlflow.source.type": "LOCAL"}}'), source_type='code'>, tags=[<InputTag: key='mlflow.data.context', value='train'>]>,
#   <DatasetInput: dataset=<Dataset: digest='cdcfc2bc', name='dataset', profile='{"num_rows": 49164, "num_elements": 245820}', schema=('{"mlflow_colspec": [{"type": "double", "name": "total_amount", "required": '
#   'true}, {"type": "double", "name": "trip_distance", "required": true}, '
#   '{"type": "double", "name": "passenger_count", "required": true}, {"type": '
#   '"integer", "name": "PULocationID", "required": true}, {"type": "integer", '
#   '"name": "DOLocationID", "required": true}]}'), source=('{"tags": {"mlflow.user": "emelidral", "mlflow.source.name": '
#   '"/opt/homebrew/Caskroom/miniconda/base/envs/iml_env/lib/python3.11/site-packages/ipykernel_launcher.py", '
#   '"mlflow.source.type": "LOCAL"}}'), source_type='code'>, tags=[<InputTag: key='mlflow.data.context', value='eval'>]>]>>,
#  <Run: data=<RunData: metrics={'rmse': 4.750436506516514}, params={'base_score': 'None',
#   'booster': 'None',
#   'colsample_bylevel': 'None',
#   'colsample_bynode': 'None',
#   'colsample_bytree': 'None',
#   'custom_metric': 'None',
#   'device': 'None',
#   'early_stopping_rounds': 'None',
#   'eval_metric': 'None',
#   'gamma': 'None',
#   'grow_policy': 'None',
#   'interaction_constraints': 'None',
#   'learning_rate': 'None',
#   'max_bin': 'None',
#   'max_cat_threshold': 'None',
#   'max_cat_to_onehot': 'None',
#   'max_delta_step': 'None',
#   'max_depth': '12',
#   'max_leaves': 'None',
#   'maximize': 'None',
#   'min_child_weight': '0.9148825062962216',
#   'monotone_constraints': 'None',
#   'multi_strategy': 'None',
#   'n_jobs': 'None',
#   'num_boost_round': '100',
#   'num_parallel_tree': 'None',
#   'objective': 'reg:squarederror',
#   'random_state': 'None',
#   'reg_alpha': '0.0005871514639172826',
#   'reg_lambda': 'None',
#   'sampling_method': 'None',
#   'scale_pos_weight': 'None',
#   'subsample': 'None',
#   'tree_method': 'None',
#   'validate_parameters': 'None',
#   'verbose_eval': 'True',
#   'verbosity': 'None'}, tags={'mlflow.log-model.history': '[{"run_id": "682ad9a69447431eb98111e7f170e11e", '
#                               '"artifact_path": "model", "utc_time_created": '
#                               '"2025-02-10 08:29:09.421550", "model_uuid": '
#                               '"d27f7ec8faeb49d6b539418d94b33b55", "flavors": '
#                               '{"python_function": {"loader_module": '
#                               '"mlflow.xgboost", "python_version": "3.11.11", '
#                               '"data": "model.xgb", "env": {"conda": '
#                               '"conda.yaml", "virtualenv": "python_env.yaml"}}, '
#                               '"xgboost": {"xgb_version": "2.1.4", "data": '
#                               '"model.xgb", "model_class": '
#                               '"xgboost.sklearn.XGBRegressor", "model_format": '
#                               '"xgb", "code": null}}}, {"run_id": '
#                               '"682ad9a69447431eb98111e7f170e11e", '
#                               '"artifact_path": "model", "utc_time_created": '
#                               '"2025-02-10 08:29:12.559307", "model_uuid": '
#                               '"7c826235bcb34f3989d7b9d4adea5b70", "flavors": '
#                               '{"python_function": {"loader_module": '
#                               '"mlflow.xgboost", "python_version": "3.11.11", '
#                               '"data": "model.xgb", "env": {"conda": '
#                               '"conda.yaml", "virtualenv": "python_env.yaml"}}, '
#                               '"xgboost": {"xgb_version": "2.1.4", "data": '
#                               '"model.xgb", "model_class": '
#                               '"xgboost.sklearn.XGBRegressor", "model_format": '
#                               '"xgb", "code": null}}}, {"run_id": '
#                               '"682ad9a69447431eb98111e7f170e11e", '
#                               '"artifact_path": "model", "utc_time_created": '
#                               '"2025-02-10 08:29:16.234344", "model_uuid": '
#                               '"9bbfbe32285d4d87a54a6634c3636f3c", "flavors": '
#                               '{"python_function": {"loader_module": '
#                               '"mlflow.xgboost", "python_version": "3.11.11", '
#                               '"data": "model.xgb", "env": {"conda": '
#                               '"conda.yaml", "virtualenv": "python_env.yaml"}}, '
#                               '"xgboost": {"xgb_version": "2.1.4", "data": '
#                               '"model.xgb", "model_class": '
#                               '"xgboost.sklearn.XGBRegressor", "model_format": '
#                               '"xgb", "code": null}}}, {"run_id": '
#                               '"682ad9a69447431eb98111e7f170e11e", '
#                               '"artifact_path": "model", "utc_time_created": '
#                               '"2025-02-10 08:29:19.347633", "model_uuid": '
#                               '"7e4a151c245b494a926429a22f016ce2", "flavors": '
#                               '{"python_function": {"loader_module": '
#                               '"mlflow.xgboost", "python_version": "3.11.11", '
#                               '"data": "model.xgb", "env": {"conda": '
#                               '"conda.yaml", "virtualenv": "python_env.yaml"}}, '
#                               '"xgboost": {"xgb_version": "2.1.4", "data": '
#                               '"model.xgb", "model_class": '
#                               '"xgboost.sklearn.XGBRegressor", "model_format": '
#                               '"xgb", "code": null}}}, {"run_id": '
#                               '"682ad9a69447431eb98111e7f170e11e", '
#                               '"artifact_path": "model", "utc_time_created": '
#                               '"2025-02-10 08:30:42.332049", "model_uuid": '
#                               '"71b1aa5bb6ea42859fdb852eca81e573", "flavors": '
#                               '{"python_function": {"loader_module": '
#                               '"mlflow.xgboost", "python_version": "3.11.11", '
#                               '"data": "model.xgb", "env": {"conda": '
#                               '"conda.yaml", "virtualenv": "python_env.yaml"}}, '
#                               '"xgboost": {"xgb_version": "2.1.4", "data": '
#                               '"model.xgb", "model_class": '
#                               '"xgboost.sklearn.XGBRegressor", "model_format": '
#                               '"xgb", "code": null}}}, {"run_id": '
#                               '"682ad9a69447431eb98111e7f170e11e", '
#                               '"artifact_path": "model", "utc_time_created": '
#                               '"2025-02-10 08:30:45.493220", "model_uuid": '
#                               '"702b2ad0b0574c3997a06b608327dd6f", "flavors": '
#                               '{"python_function": {"loader_module": '
#                               '"mlflow.xgboost", "python_version": "3.11.11", '
#                               '"data": "model.xgb", "env": {"conda": '
#                               '"conda.yaml", "virtualenv": "python_env.yaml"}}, '
#                               '"xgboost": {"xgb_version": "2.1.4", "data": '
#                               '"model.xgb", "model_class": '
#                               '"xgboost.sklearn.XGBRegressor", "model_format": '
#                               '"xgb", "code": null}}}]',
#   'mlflow.runName': 'persistent-seal-810',
#   'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/iml_env/lib/python3.11/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'emelidral'}>, info=<RunInfo: artifact_uri='/Users/emelidral/Dev/iml/mlruns/1/682ad9a69447431eb98111e7f170e11e/artifacts', end_time=1739176380988, experiment_id='1', lifecycle_stage='active', run_id='682ad9a69447431eb98111e7f170e11e', run_name='persistent-seal-810', run_uuid='682ad9a69447431eb98111e7f170e11e', start_time=1739176148699, status='FINISHED', user_id='emelidral'>, inputs=<RunInputs: dataset_inputs=[<DatasetInput: dataset=<Dataset: digest='b253d6c6', name='dataset', profile=('{"features_shape": [52837, 5], "features_size": 264185, "features_nbytes": '
#   '1056740}'), schema=('{"mlflow_tensorspec": {"features": "[{\\"type\\": \\"tensor\\", '
#   '\\"tensor-spec\\": {\\"dtype\\": \\"float32\\", \\"shape\\": [-1, 5]}}]", '
#   '"targets": null}}'), source=('{"tags": {"mlflow.user": "emelidral", "mlflow.source.name": '
#   '"/opt/homebrew/Caskroom/miniconda/base/envs/iml_env/lib/python3.11/site-packages/ipykernel_launcher.py", '
#   '"mlflow.source.type": "LOCAL"}}'), source_type='code'>, tags=[<InputTag: key='mlflow.data.context', value='train'>]>,
#   <DatasetInput: dataset=<Dataset: digest='cdcfc2bc', name='dataset', profile='{"num_rows": 49164, "num_elements": 245820}', schema=('{"mlflow_colspec": [{"type": "double", "name": "total_amount", "required": '
#   'true}, {"type": "double", "name": "trip_distance", "required": true}, '
#   '{"type": "double", "name": "passenger_count", "required": true}, {"type": '
#   '"integer", "name": "PULocationID", "required": true}, {"type": "integer", '
#   '"name": "DOLocationID", "required": true}]}'), source=('{"tags": {"mlflow.user": "emelidral", "mlflow.source.name": '
#   '"/opt/homebrew/Caskroom/miniconda/base/envs/iml_env/lib/python3.11/site-packages/ipykernel_launcher.py", '
#   '"mlflow.source.type": "LOCAL"}}'), source_type='code'>, tags=[<InputTag: key='mlflow.data.context', value='eval'>]>]>>,
#  <Run: data=<RunData: metrics={}, params={'base_score': 'None',
#   'booster': 'None',
#   'colsample_bylevel': 'None',
#   'colsample_bynode': 'None',
#   'colsample_bytree': 'None',
#   'custom_metric': 'None',
#   'device': 'None',
#   'early_stopping_rounds': 'None',
#   'eval_metric': 'None',
#   'gamma': 'None',
#   'grow_policy': 'None',
#   'interaction_constraints': 'None',
#   'learning_rate': 'None',
#   'max_bin': 'None',
#   'max_cat_threshold': 'None',
#   'max_cat_to_onehot': 'None',
#   'max_delta_step': 'None',
#   'max_depth': '16',
#   'max_leaves': 'None',
#   'maximize': 'None',
#   'min_child_weight': '0.43956421800896833',
#   'monotone_constraints': 'None',
#   'multi_strategy': 'None',
#   'n_jobs': 'None',
#   'num_boost_round': '100',
#   'num_parallel_tree': 'None',
#   'objective': 'reg:squarederror',
#   'random_state': 'None',
#   'reg_alpha': '0.010580101888746512',
#   'reg_lambda': 'None',
#   'sampling_method': 'None',
#   'scale_pos_weight': 'None',
#   'subsample': 'None',
#   'tree_method': 'None',
#   'validate_parameters': 'None',
#   'verbose_eval': 'True',
#   'verbosity': 'None'}, tags={'mlflow.autologging': 'xgboost',
#   'mlflow.log-model.history': '[{"run_id": "ccd29bb220864579bd9faf1d84c72030", '
#                               '"artifact_path": "model", "utc_time_created": '
#                               '"2025-02-10 08:29:05.657924", "model_uuid": '
#                               '"487b49921be04b5e96725b460755f79c", "flavors": '
#                               '{"python_function": {"loader_module": '
#                               '"mlflow.xgboost", "python_version": "3.11.11", '
#                               '"data": "model.xgb", "env": {"conda": '
#                               '"conda.yaml", "virtualenv": "python_env.yaml"}}, '
#                               '"xgboost": {"xgb_version": "2.1.4", "data": '
#                               '"model.xgb", "model_class": '
#                               '"xgboost.sklearn.XGBRegressor", "model_format": '
#                               '"xgb", "code": null}}}]',
#   'mlflow.runName': 'upset-robin-279',
#   'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/iml_env/lib/python3.11/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'emelidral'}>, info=<RunInfo: artifact_uri='/Users/emelidral/Dev/iml/mlruns/1/ccd29bb220864579bd9faf1d84c72030/artifacts', end_time=1739176148471, experiment_id='1', lifecycle_stage='active', run_id='ccd29bb220864579bd9faf1d84c72030', run_name='upset-robin-279', run_uuid='ccd29bb220864579bd9faf1d84c72030', start_time=1739176143474, status='FINISHED', user_id='emelidral'>, inputs=<RunInputs: dataset_inputs=[<DatasetInput: dataset=<Dataset: digest='b253d6c6', name='dataset', profile=('{"features_shape": [52837, 5], "features_size": 264185, "features_nbytes": '
#   '1056740}'), schema=('{"mlflow_tensorspec": {"features": "[{\\"type\\": \\"tensor\\", '
#   '\\"tensor-spec\\": {\\"dtype\\": \\"float32\\", \\"shape\\": [-1, 5]}}]", '
#   '"targets": null}}'), source=('{"tags": {"mlflow.user": "emelidral", "mlflow.source.name": '
#   '"/opt/homebrew/Caskroom/miniconda/base/envs/iml_env/lib/python3.11/site-packages/ipykernel_launcher.py", '
#   '"mlflow.source.type": "LOCAL"}}'), source_type='code'>, tags=[<InputTag: key='mlflow.data.context', value='train'>]>,
#   <DatasetInput: dataset=<Dataset: digest='cdcfc2bc', name='dataset', profile='{"num_rows": 49164, "num_elements": 245820}', schema=('{"mlflow_colspec": [{"type": "double", "name": "total_amount", "required": '
#   'true}, {"type": "double", "name": "trip_distance", "required": true}, '
#   '{"type": "double", "name": "passenger_count", "required": true}, {"type": '
#   '"integer", "name": "PULocationID", "required": true}, {"type": "integer", '
#   '"name": "DOLocationID", "required": true}]}'), source=('{"tags": {"mlflow.user": "emelidral", "mlflow.source.name": '
#   '"/opt/homebrew/Caskroom/miniconda/base/envs/iml_env/lib/python3.11/site-packages/ipykernel_launcher.py", '
#   '"mlflow.source.type": "LOCAL"}}'), source_type='code'>, tags=[<InputTag: key='mlflow.data.context', value='eval'>]>]>>,
#  <Run: data=<RunData: metrics={}, params={'base_score': 'None',
#   'booster': 'None',
#   'colsample_bylevel': 'None',
#   'colsample_bynode': 'None',
#   'colsample_bytree': 'None',
#   'custom_metric': 'None',
#   'device': 'None',
#   'early_stopping_rounds': 'None',
#   'eval_metric': 'None',
#   'gamma': 'None',
#   'grow_policy': 'None',
#   'interaction_constraints': 'None',
#   'learning_rate': 'None',
#   'max_bin': 'None',
#   'max_cat_threshold': 'None',
#   'max_cat_to_onehot': 'None',
#   'max_delta_step': 'None',
#   'max_depth': '16',
#   'max_leaves': 'None',
#   'maximize': 'None',
#   'min_child_weight': '0.17720729205535485',
#   'monotone_constraints': 'None',
#   'multi_strategy': 'None',
#   'n_jobs': 'None',
#   'num_boost_round': '100',
#   'num_parallel_tree': 'None',
#   'objective': 'reg:squarederror',
#   'random_state': 'None',
#   'reg_alpha': '0.08123964894558523',
#   'reg_lambda': 'None',
#   'sampling_method': 'None',
#   'scale_pos_weight': 'None',
#   'subsample': 'None',
#   'tree_method': 'None',
#   'validate_parameters': 'None',
#   'verbose_eval': 'True',
#   'verbosity': 'None'}, tags={'mlflow.autologging': 'xgboost',
#   'mlflow.log-model.history': '[{"run_id": "9cbfb87c1d3b425aaadee4efe7c8ee18", '
#                               '"artifact_path": "model", "utc_time_created": '
#                               '"2025-02-10 08:28:44.705027", "model_uuid": '
#                               '"cbac7c5368c247798a4f5dfa918ff370", "flavors": '
#                               '{"python_function": {"loader_module": '
#                               '"mlflow.xgboost", "python_version": "3.11.11", '
#                               '"data": "model.xgb", "env": {"conda": '
#                               '"conda.yaml", "virtualenv": "python_env.yaml"}}, '
#                               '"xgboost": {"xgb_version": "2.1.4", "data": '
#                               '"model.xgb", "model_class": '
#                               '"xgboost.sklearn.XGBRegressor", "model_format": '
#                               '"xgb", "code": null}}}]',
#   'mlflow.runName': 'sneaky-auk-665',
#   'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/iml_env/lib/python3.11/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'emelidral'}>, info=<RunInfo: artifact_uri='/Users/emelidral/Dev/iml/mlruns/1/9cbfb87c1d3b425aaadee4efe7c8ee18/artifacts', end_time=1739176127905, experiment_id='1', lifecycle_stage='active', run_id='9cbfb87c1d3b425aaadee4efe7c8ee18', run_name='sneaky-auk-665', run_uuid='9cbfb87c1d3b425aaadee4efe7c8ee18', start_time=1739176122508, status='FINISHED', user_id='emelidral'>, inputs=<RunInputs: dataset_inputs=[<DatasetInput: dataset=<Dataset: digest='b253d6c6', name='dataset', profile=('{"features_shape": [52837, 5], "features_size": 264185, "features_nbytes": '
#   '1056740}'), schema=('{"mlflow_tensorspec": {"features": "[{\\"type\\": \\"tensor\\", '
#   '\\"tensor-spec\\": {\\"dtype\\": \\"float32\\", \\"shape\\": [-1, 5]}}]", '
#   '"targets": null}}'), source=('{"tags": {"mlflow.user": "emelidral", "mlflow.source.name": '
#   '"/opt/homebrew/Caskroom/miniconda/base/envs/iml_env/lib/python3.11/site-packages/ipykernel_launcher.py", '
#   '"mlflow.source.type": "LOCAL"}}'), source_type='code'>, tags=[<InputTag: key='mlflow.data.context', value='train'>]>,
#   <DatasetInput: dataset=<Dataset: digest='cdcfc2bc', name='dataset', profile='{"num_rows": 49164, "num_elements": 245820}', schema=('{"mlflow_colspec": [{"type": "double", "name": "total_amount", "required": '
#   'true}, {"type": "double", "name": "trip_distance", "required": true}, '
#   '{"type": "double", "name": "passenger_count", "required": true}, {"type": '
#   '"integer", "name": "PULocationID", "required": true}, {"type": "integer", '
#   '"name": "DOLocationID", "required": true}]}'), source=('{"tags": {"mlflow.user": "emelidral", "mlflow.source.name": '
#   '"/opt/homebrew/Caskroom/miniconda/base/envs/iml_env/lib/python3.11/site-packages/ipykernel_launcher.py", '
#   '"mlflow.source.type": "LOCAL"}}'), source_type='code'>, tags=[<InputTag: key='mlflow.data.context', value='eval'>]>]>>,
#  <Run: data=<RunData: metrics={}, params={'base_score': 'None',
#   'booster': 'None',
#   'colsample_bylevel': 'None',
#   'colsample_bynode': 'None',
#   'colsample_bytree': 'None',
#   'custom_metric': 'None',
#   'device': 'None',
#   'early_stopping_rounds': 'None',
#   'eval_metric': 'None',
#   'gamma': 'None',
#   'grow_policy': 'None',
#   'interaction_constraints': 'None',
#   'learning_rate': 'None',
#   'max_bin': 'None',
#   'max_cat_threshold': 'None',
#   'max_cat_to_onehot': 'None',
#   'max_delta_step': 'None',
#   'max_depth': '12',
#   'max_leaves': 'None',
#   'maximize': 'None',
#   'min_child_weight': '2.610475617120329',
#   'monotone_constraints': 'None',
#   'multi_strategy': 'None',
#   'n_jobs': 'None',
#   'num_boost_round': '100',
#   'num_parallel_tree': 'None',
#   'objective': 'reg:squarederror',
#   'random_state': 'None',
#   'reg_alpha': '0.00020357727549267905',
#   'reg_lambda': 'None',
#   'sampling_method': 'None',
#   'scale_pos_weight': 'None',
#   'subsample': 'None',
#   'tree_method': 'None',
#   'validate_parameters': 'None',
#   'verbose_eval': 'True',
#   'verbosity': 'None'}, tags={'mlflow.autologging': 'xgboost',
#   'mlflow.log-model.history': '[{"run_id": "465c18ec782d44baaa291e4bfae4be83", '
#                               '"artifact_path": "model", "utc_time_created": '
#                               '"2025-02-10 08:27:02.215979", "model_uuid": '
#                               '"1184f0aa3f1c48c094a1d0490e36cebc", "flavors": '
#                               '{"python_function": {"loader_module": '
#                               '"mlflow.xgboost", "python_version": "3.11.11", '
#                               '"data": "model.xgb", "env": {"conda": '
#                               '"conda.yaml", "virtualenv": "python_env.yaml"}}, '
#                               '"xgboost": {"xgb_version": "2.1.4", "data": '
#                               '"model.xgb", "model_class": '
#                               '"xgboost.sklearn.XGBRegressor", "model_format": '
#                               '"xgb", "code": null}}}]',
#   'mlflow.runName': 'languid-steed-293',
#   'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/iml_env/lib/python3.11/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'emelidral'}>, info=<RunInfo: artifact_uri='/Users/emelidral/Dev/iml/mlruns/1/465c18ec782d44baaa291e4bfae4be83/artifacts', end_time=1739176024931, experiment_id='1', lifecycle_stage='active', run_id='465c18ec782d44baaa291e4bfae4be83', run_name='languid-steed-293', run_uuid='465c18ec782d44baaa291e4bfae4be83', start_time=1739176021359, status='FINISHED', user_id='emelidral'>, inputs=<RunInputs: dataset_inputs=[<DatasetInput: dataset=<Dataset: digest='b253d6c6', name='dataset', profile=('{"features_shape": [52837, 5], "features_size": 264185, "features_nbytes": '
#   '1056740}'), schema=('{"mlflow_tensorspec": {"features": "[{\\"type\\": \\"tensor\\", '
#   '\\"tensor-spec\\": {\\"dtype\\": \\"float32\\", \\"shape\\": [-1, 5]}}]", '
#   '"targets": null}}'), source=('{"tags": {"mlflow.user": "emelidral", "mlflow.source.name": '
#   '"/opt/homebrew/Caskroom/miniconda/base/envs/iml_env/lib/python3.11/site-packages/ipykernel_launcher.py", '
#   '"mlflow.source.type": "LOCAL"}}'), source_type='code'>, tags=[<InputTag: key='mlflow.data.context', value='train'>]>,
#   <DatasetInput: dataset=<Dataset: digest='cdcfc2bc', name='dataset', profile='{"num_rows": 49164, "num_elements": 245820}', schema=('{"mlflow_colspec": [{"type": "double", "name": "total_amount", "required": '
#   'true}, {"type": "double", "name": "trip_distance", "required": true}, '
#   '{"type": "double", "name": "passenger_count", "required": true}, {"type": '
#   '"integer", "name": "PULocationID", "required": true}, {"type": "integer", '
#   '"name": "DOLocationID", "required": true}]}'), source=('{"tags": {"mlflow.user": "emelidral", "mlflow.source.name": '
#   '"/opt/homebrew/Caskroom/miniconda/base/envs/iml_env/lib/python3.11/site-packages/ipykernel_launcher.py", '
#   '"mlflow.source.type": "LOCAL"}}'), source_type='code'>, tags=[<InputTag: key='mlflow.data.context', value='eval'>]>]>>]

# %%
runs[0]
# Out:
# <Run: data=<RunData: metrics={'rmse': 4.727144313107067}, params={'base_score': 'None',
#  'booster': 'None',
#  'colsample_bylevel': 'None',
#  'colsample_bynode': 'None',
#  'colsample_bytree': 'None',
#  'custom_metric': 'None',
#  'device': 'None',
#  'early_stopping_rounds': 'None',
#  'eval_metric': 'None',
#  'gamma': 'None',
#  'grow_policy': 'None',
#  'interaction_constraints': 'None',
#  'learning_rate': 'None',
#  'max_bin': 'None',
#  'max_cat_threshold': 'None',
#  'max_cat_to_onehot': 'None',
#  'max_delta_step': 'None',
#  'max_depth': '7',
#  'max_leaves': 'None',
#  'maximize': 'None',
#  'min_child_weight': '1.0657267002989208',
#  'monotone_constraints': 'None',
#  'multi_strategy': 'None',
#  'n_jobs': 'None',
#  'num_boost_round': '100',
#  'num_parallel_tree': 'None',
#  'objective': 'reg:squarederror',
#  'random_state': 'None',
#  'reg_alpha': '8.676949985124119e-05',
#  'reg_lambda': 'None',
#  'sampling_method': 'None',
#  'scale_pos_weight': 'None',
#  'subsample': 'None',
#  'tree_method': 'None',
#  'validate_parameters': 'None',
#  'verbose_eval': 'True',
#  'verbosity': 'None'}, tags={'mlflow.log-model.history': '[{"run_id": "370958a8e9dd4b1db4c15d033d97005d", '
#                              '"artifact_path": "model", "utc_time_created": '
#                              '"2025-02-10 08:33:28.536514", "model_uuid": '
#                              '"226fd86c00e7499385c1dc3147b39ef0", "flavors": '
#                              '{"python_function": {"loader_module": '
#                              '"mlflow.xgboost", "python_version": "3.11.11", '
#                              '"data": "model.xgb", "env": {"conda": '
#                              '"conda.yaml", "virtualenv": "python_env.yaml"}}, '
#                              '"xgboost": {"xgb_version": "2.1.4", "data": '
#                              '"model.xgb", "model_class": '
#                              '"xgboost.sklearn.XGBRegressor", "model_format": '
#                              '"xgb", "code": null}}}]',
#  'mlflow.runName': 'delicate-cow-543',
#  'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/iml_env/lib/python3.11/site-packages/ipykernel_launcher.py',
#  'mlflow.source.type': 'LOCAL',
#  'mlflow.user': 'emelidral'}>, info=<RunInfo: artifact_uri='/Users/emelidral/Dev/iml/mlruns/1/370958a8e9dd4b1db4c15d033d97005d/artifacts', end_time=1739176411407, experiment_id='1', lifecycle_stage='active', run_id='370958a8e9dd4b1db4c15d033d97005d', run_name='delicate-cow-543', run_uuid='370958a8e9dd4b1db4c15d033d97005d', start_time=1739176408203, status='FINISHED', user_id='emelidral'>, inputs=<RunInputs: dataset_inputs=[<DatasetInput: dataset=<Dataset: digest='b253d6c6', name='dataset', profile=('{"features_shape": [52837, 5], "features_size": 264185, "features_nbytes": '
#  '1056740}'), schema=('{"mlflow_tensorspec": {"features": "[{\\"type\\": \\"tensor\\", '
#  '\\"tensor-spec\\": {\\"dtype\\": \\"float32\\", \\"shape\\": [-1, 5]}}]", '
#  '"targets": null}}'), source=('{"tags": {"mlflow.user": "emelidral", "mlflow.source.name": '
#  '"/opt/homebrew/Caskroom/miniconda/base/envs/iml_env/lib/python3.11/site-packages/ipykernel_launcher.py", '
#  '"mlflow.source.type": "LOCAL"}}'), source_type='code'>, tags=[<InputTag: key='mlflow.data.context', value='train'>]>,
#  <DatasetInput: dataset=<Dataset: digest='cdcfc2bc', name='dataset', profile='{"num_rows": 49164, "num_elements": 245820}', schema=('{"mlflow_colspec": [{"type": "double", "name": "total_amount", "required": '
#  'true}, {"type": "double", "name": "trip_distance", "required": true}, '
#  '{"type": "double", "name": "passenger_count", "required": true}, {"type": '
#  '"integer", "name": "PULocationID", "required": true}, {"type": "integer", '
#  '"name": "DOLocationID", "required": true}]}'), source=('{"tags": {"mlflow.user": "emelidral", "mlflow.source.name": '
#  '"/opt/homebrew/Caskroom/miniconda/base/envs/iml_env/lib/python3.11/site-packages/ipykernel_launcher.py", '
#  '"mlflow.source.type": "LOCAL"}}'), source_type='code'>, tags=[<InputTag: key='mlflow.data.context', value='eval'>]>]>>

# %%
type(runs[0].data.metrics['rmse'])

# %%
type(runs[0].info.run_id)
# Out:
# str

# %%
for run in runs:
    print(f"run_id:{run.info.run_id}, rmse:{run.data.metrics['rmse']}")
# Out:
# run_id:370958a8e9dd4b1db4c15d033d97005d, rmse:4.727144313107067
# run_id:7c5a6121cfb14fcb90956ba3b6345f14, rmse:4.968081541786119
# run_id:e7fa20b742ff4661b02eb42696d5b363, rmse:5.031111100380337
# run_id:266d4e30d42b4a6fb70685b429117374, rmse:4.9575708531289
# run_id:eef5837f253c4df4b936d27f3a1bda2f, rmse:5.244096627656075
# run_id:351a8aca818642ecaa31f88741b25cd1, rmse:4.799095475534573
# run_id:682ad9a69447431eb98111e7f170e11e, rmse:4.750436506516514
# run_id:9f65833df16447bfbeb94fb88d985039, rmse:6.671806092249931

# %% [markdown]
# ## Log model

# %%
study.best_params
# Out:
# {'max_depth': 7,
#  'reg_alpha': 8.676949985124119e-05,
#  'min_child_weight': 1.0657267002989208}

# %%
model = xgboost.XGBRegressor(**study.best_params)
model.fit(X_train, y_tra)
mlflow.xgboost.log_model(model, artifact_path='mlflow_models')
# Out:
# 2025/02/10 16:00:08 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/opt/homebrew/Caskroom/miniconda/base/envs/iml_env/lib/python3.11/site-packages/mlflow/types/utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2025/02/10 16:00:08 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/opt/homebrew/Caskroom/miniconda/base/envs/iml_env/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [16:00:08] WARNING: /Users/runner/work/xgboost/xgboost/src/c_api/c_api.cc:1374: Saving model in the UBJSON format as default.  You can use file extension: `json`, `ubj` or `deprecated` to choose between formats."
# /opt/homebrew/Caskroom/miniconda/base/envs/iml_env/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [16:00:11] WARNING: /Users/runner/work/xgboost/xgboost/src/c_api/c_api.cc:1374: Saving model in the UBJSON format as default.  You can use file extension: `json`, `ubj` or `deprecated` to choose between formats.
#   warnings.warn(smsg, UserWarning)
# 2025/02/10 16:00:14 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
